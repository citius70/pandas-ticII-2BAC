# %% [markdown]
# # Ejercicios de visualización de datos

# %% [markdown]
# En este notebook aprenderás a crear diferentes tipos de gráficos utilizando solo `pandas`. No necesitaremos importar bibliotecas adicionales como `matplotlib` o `seaborn`, ya que `pandas` permite crear gráficos directamente desde DataFrames y Series.
#
# ---

# %%
import pandas as pd

# Cargar datos de ejemplo
url = "https://drive.google.com/uc?export=download&id=1HbZ6KvPgjnGGwi74lkHUr8bwyHd_v_42"
df = pd.read_csv(url)

# Mostrar el DataFrame
df.head()
# Out:
#    Unnamed: 0       Fecha  Maquina   Turno  Produccion  Horas_parada Averia
# 0           0  2025-04-14  Torno 1  Mañana       152.0           1.6     Sí
# 1           1  2025-04-14  Torno 1   Tarde       121.0           1.2     Sí
# 2           2  2025-04-14  Torno 1   Noche       124.0           0.9     No
# 3           3  2025-04-14  Torno 2  Mañana       153.0           1.4     Sí
# 4           4  2025-04-14  Torno 2   Tarde        51.0           1.4     No

# %% [markdown]
# ## Ejercicio 1: Gráfico de líneas
#
# Crea un gráfico de líneas con las columnas numéricas del DataFrame. Puedes usar `df.plot()` directamente.
#
# ➡️ ¿Qué observas en la tendencia?

# %%
df.plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Ejercicio 2: Gráfico de barras
#
# Selecciona una columna categórica (por ejemplo, una columna con regiones o nombres) y otra numérica.
#
# Crea un gráfico de barras usando `.plot(kind='bar')`.
#
# ➡️ Tip: Usa `df.groupby(...).sum()` para preparar los datos si es necesario.

# %%
# Ejemplo de agrupamiento (modifica según tu dataset)
# datos_bar = df.groupby('Categoria')['Ventas'].sum()
datos_bar.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # Ejemplo de agrupamiento (modifica según tu dataset)
#       2 # datos_bar = df.groupby('Categoria')['Ventas'].sum()
# ----> 3 datos_bar.plot(kind='bar')
#
# NameError: name 'datos_bar' is not defined

# %% [markdown]
# ## Ejercicio 3: Gráfico de pastel
#
# Usa `.value_counts()` sobre una columna categórica y crea un gráfico tipo pastel con `.plot(kind='pie')`.
#
# ➡️ Asegúrate de que el resultado sea una Serie, no un DataFrame.

# %%
# df['Categoria'].value_counts().plot(kind='pie')

# %% [markdown]
# ## Ejercicio 4: Diagrama de dispersión
#
# Crea un gráfico de dispersión entre dos columnas numéricas, por ejemplo, `Edad` y `Ingresos`.
#
# Usa `.plot(kind='scatter', x='col1', y='col2')`

# %%
# df.plot(kind='scatter', x='Edad', y='Ingresos')

# %% [markdown]
# ## Ejercicio 5: Diagrama de caja
#
# Visualiza la distribución de una o varias columnas numéricas con `.plot(kind='box')`.
#
# ➡️ ¿Hay valores atípicos?

# %%
# df[['Edad', 'Ingresos']].plot(kind='box')

# %% [markdown]
# ## Actividad final
#
# Usa los tipos de gráficos aprendidos para responder a una de estas preguntas:
#
# - ¿Qué categoría tiene mayor representación?
# - ¿Cómo varían los valores a lo largo del tiempo?
# - ¿Existen correlaciones entre variables?
#
# Crea al menos **dos visualizaciones distintas** para apoyar tu respuesta.
