# %% [markdown]
# # 🍷 Análisis de Calidad de Vinos (Red Wine Dataset)
#
# Este cuaderno usa únicamente `pandas` para explorar visualmente el dataset de vinos tintos, que contiene información química de cada vino junto con su calidad numérica.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Cargar el dataset (usa ; como separador)
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/winequality-red.csv"
df = pd.read_csv("datasets/winequality-red.csv")

# Mostrar primeras filas
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ## 1. Distribución del nivel de alcohol

# %%
df['alcohol'].plot(kind='hist', bins=15, title='Distribución de Alcohol')
plt.xlabel('Alcohol (%)')
plt.show()

# %% [markdown]
# ## 2. Alcohol por nivel de calidad (Boxplot)

# %%
df.boxplot(column='alcohol', by='quality')
plt.title('Alcohol por Nivel de Calidad')
plt.suptitle('')
plt.xlabel('Calidad')
plt.ylabel('Alcohol (%)')
plt.show()

# %% [markdown]
# ## 3. Promedio de pH por calidad

# %%
df.groupby('quality')['pH'].mean().plot(kind='bar', title='Promedio de pH por Calidad')
plt.ylabel('pH')
plt.show()

# %% [markdown]
# ## 4. Relación entre alcohol y calidad (dispersión)

# %%
df.plot(x='alcohol', y='quality', kind='scatter', title='Relación entre Alcohol y Calidad')
plt.show()
