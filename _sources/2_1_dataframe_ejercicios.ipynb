# %% [markdown]
# # Ejercicicio sobre creación de dataframes

# %% [markdown]
# ## Ejercicio 1. Crear un dataframe **manualmente**

# %% [markdown]
# **Objetivo**: Crear un DataFrame que contenga información sobre algunos estudiantes, incluyendo su nombre, edad y calificación final.

# %% [markdown]
# **Salida Esperada**: Cuando ejecutes el código, deberías ver una salida similar a esta:
#
# ![Pandas](imagenes/ejercicio01_salida.png.svg)
#
# <p align="center">
#     <img src="imagenes/ejercicio01_salida.png" width="20%">
# </p>
#
# **Pasos**:
# 1. Importa la biblioteca `pandas`
# 2. Define los datos de los estudiantes en un diccionario que deseas incluir en el DataFrame
# 3. Crea el dataframe a partir de los datos del diccionario
# 4. Muestra el dataframe

# %%
# Paso 1. Importa la biblioteca `pandas`
import pandas as pd

# Paso 2. Define los datos de los estudiantes en un diccionario que deseas incluir en el DataFrame
estudiantes = {
    'Nombre': ['Ana', 'Luis', 'Carlos', 'María'],
    'Edad': [20, 21, 19, 22],
    'Calificación': [9, 8, 7, 10] 
}

# Paso 3. Crea el dataframe a partir de los datos del diccionario
df= pd.DataFrame(estudiantes)

# Paso 4: Muestra el dataframe
df
# Out:
#    Nombre  Edad  Calificación
# 0     Ana    20             9
# 1    Luis    21             8
# 2  Carlos    19             7
# 3   María    22            10

# %% [markdown]
#  ## Ejercicio 2. Crear un dataframe **importando un archivo** CSV

# %% [markdown]
# **Objetivo**: Crear un DataFrame a partir de un archivo Excel publicado en internet.
#
# **Salida Esperada**: Cuando ejecutes el código, deberías ver una salida similar a esta:
# <p align="center">
#     <img src="imagenes/dataframe_spotify.png" width="50%">
# </p>
#
# **Pasos**:
#
# Descargar el archivo:
#
# 1. Visita la siguiente web: https://mavenanalytics.io/data-playground
# 2. Descarga el archivo zip de datos correspondiente a la "Video Game Sales" (Ventas de 64.012 videojuegos entre 1971-2024)
# 3. Descomprime el archivo. Una vez hecho esto, verás dos archivos csv. El que utilizarás es "**vgchartz-2024.csv**"
#
# Importar pandas:
#
# 4. Importa la biblioteca pandas
#
# Crear el DataFrame:
#
# 5. Utiliza el método "read_csv" para crear el datafame. Puedes llamarlo "data", "data_ventas"....
#     * ¡Atención! Además del nombre del archivo "vgchartz-2024.csv", tienes que indicar el path al mismo.
#         * En mi caso df = pd.read_csv(r"C:\Users\alber\Desktop\vgchartz-2024.csv")
# 6. Visualiza el DataFrame.

# %%
# Paso 1: Visita la siguiente web: https://mavenanalytics.io/data-playground
# Paso 2: Descarga el archivo zip de datos correspondiente a la "Historia completa de streaming de un usuario de Spotify" (Spotify Streaming History)
# Paso 3: Descomprime el archivo. Una vez hecho esto, verás dos archivos csv. El que utilizarás es "spotify_history.csv"
# --------------
# Paso 4: Utiliza el método "read_csv" para crear el datafame. Puedes llamarlo "data", "data_spotify"....
# Paso 4.1. ¡Atención! Además del nombre del archivo "spotify_history", tienes que indicar el path al mismo.
# En mi caso df = pd.read_csv(r"C:\Users\alber\Desktop\spotify_history.csv")
# -------------
# Paso 5: Importa la biblioteca pandas
# Paso 6: Visualiza el daframe

# ESCRIBE EL CÓDIGO AQUÍ:
import pandas as pd
df = pd.read_csv("datasets/vgchartz-2024.csv")
df
# Out:
#                                                  img  \
# 0      /games/boxart/full_6510540AmericaFrontccc.jpg
# 1      /games/boxart/full_5563178AmericaFrontccc.jpg
# 2                        /games/boxart/827563ccc.jpg
# 3      /games/boxart/full_9218923AmericaFrontccc.jpg
# 4      /games/boxart/full_4990510AmericaFrontccc.jpg
# ...                                              ...
# 64011  /games/boxart/full_2779838AmericaFrontccc.jpg
# 64012  /games/boxart/full_8031506AmericaFrontccc.jpg
# 64013  /games/boxart/full_6553045AmericaFrontccc.jpg
# 64014    /games/boxart/full_6012940JapanFrontccc.png
# 64015                      /games/boxart/default.jpg
#
#                                   title console         genre  \
# 0                    Grand Theft Auto V     PS3        Action
# 1                    Grand Theft Auto V     PS4        Action
# 2           Grand Theft Auto: Vice City     PS2        Action
# 3                    Grand Theft Auto V    X360        Action
# ...

# %% [markdown]
# **¡Enhorabuena!** Has convertido una hoja de cálculo de más de 60.000 filas en un **Dataframe** de Pandas. Este es el primer paso para aprovechar las funciones de esta librería de Python. Esto lo harás en los próximos capítulos.
