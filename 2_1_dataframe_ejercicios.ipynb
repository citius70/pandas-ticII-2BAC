# %% [markdown]
# # 📑 Ejercicicios: Creación de DataFrames (manualmente y desde archivos CSV)

# %% [markdown]
# :::{admonition} Ejercicio 1: Crear un DataFrame **manualmente**
# :class: tip
#
# **Objetivo**: Crear un DataFrame manualmente (a través de un diccionario) que contenga información sobre algunos estudiantes, incluyendo su nombre, edad y calificación final.
#
# **Salida Esperada**: Cuando ejecutes el código, deberías ver una salida similar a la siguiente.
#
# ```{figure} imagenes/ejercicio01_salida.png
# ---
# figclass: margin
# name: dataframe
# ---
# Salida del Ejercicio 1
# ```
#
# **Pasos**:
# 1. Importa la biblioteca `pandas`
# 2. Define los datos de los estudiantes en un diccionario que deseas incluir en el DataFrame
# 3. Crea el dataframe a partir de los datos del diccionario
# 4. Muestra el dataframe

# %%
# Paso 1. Importa la biblioteca `pandas`

# Paso 2. Define los datos de los estudiantes en un diccionario (dic_alum) que deseas incluir en el DataFrame
    # dic_alum = {   ??????????    }

# Paso 3. Crea el dataframe a partir de los datos del diccionario
    # dataframe = pd.???????????

# Paso 4: Muestra el dataframe

# %% [markdown]
# :::{admonition} Ejercicio 2: Crear un DataFrame **importando un archivo** CSV
# :class: tip
#
# **Objetivo**: Crear un DataFrame a partir de un **archivo CSV** publicado en internet.
#
# **Salida Esperada**: Cuando ejecutes el código, deberías ver una salida similar así.
# ```{figure} imagenes/spotify.png
# ---
# figclass: margin1
# name: dataframe1
# ---
# Salida del Ejercicio 2
# ```
#
# **Pasos**:
#
# 1. **Descargar** el archivo:
#
#     1.1. **Visita** la siguiente web: https://mavenanalytics.io/data-playground
#
#     1.2. **Descarga** el archivo zip de datos correspondiente a:
#
#     - Historia completa de streaming de un usuario de Spotify **(Spotify Streaming History)**
#
#     1.3. La carpeta descargada descomprimida se llama **"Spotify-Streaming-History.zip"**
#
#     1.4. **Descomprime** la carpeta.
#     - Una vez hecho esto, verás **dos archivos csv**. El que utilizarás es "**spotify_history.csv**"
#       - El dataset, de 25 columnas y 499 filas, contiene el historial de streaming de un usuario de Spotify, incluyendo información sobre las canciones que ha escuchado, la duración de cada canción, la fecha y hora de reproducción, entre otros detalles relacionados con su actividad en la plataforma.
#
# 2. Importar **pandas**
#
# 3. Crear el **DataFrame** a partir del archivo csv utilizando el método "read_csv". Puedes llamarlo "df", "data", "data_spotify"....
#
#     * ¡Atención! Además del nombre del archivo "spotify_history.csv", tienes que indicar el path o ruta al mismo.
#
# 4. **Visualiza** el DataFrame.

# %%
# ESCRIBE EL CÓDIGO AQUÍ:

# Paso 1. Importar pandas

# Paso 2. Crear el DataFrame a partir del archivo csv utilizando el método "read_csv". Puedes llamarlo "df", "data", "data_spotify"....
# ¡Atención! Además del nombre del archivo "spotify_history.csv", tienes que indicar el path o ruta al mismo.

# Paso 3.  Visualiza el DataFrame.

# %% [markdown]
# **¡Enhorabuena!** Has conseguido crear **Dataframes** de Pandas. Este es el primer paso para aprovechar las funciones de esta librería de Python. Esto lo harás en los próximos capítulos.
